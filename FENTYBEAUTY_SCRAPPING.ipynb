# %% [markdown]
# # scrapping

# %%
from bs4 import BeautifulSoup
from time import sleep
import time

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

browser = webdriver.Chrome(r"C:\Users\amnad\Documents\DATA_IA\PYTHON\SELENIUM\chromedriver.exe")
#browser = webdriver.Chrome(executable_path='C:/path/to/geckodriver.exe')# au cas où geckdriver.exe n'est pas dans le path ni au même endroit
browser.get('https://www.fentybeauty.com/pro-filtr/soft-matte-longwear-foundation/FB30006.html?dwvar_FB30006_color=FB0340')

# %%
browser.maximize_window()

# %% [markdown]
# ___

# %%
pages_remaining = True

while pages_remaining:
    
        #FLIP PAGES ----------------------------------------------------------------------------------------------
        
    #for load in browser.find_elements_by_css_selector('div[class = bv-content-pagination-container]'):
        
    try :
        #next_link = browser.find_element_by_css_selector('button[class = bv-content-btn bv-content-btn-pages bv-content-btn-pages-load-more bv-focusable]')
        #next_link = browser.find_element_by_xpath('//*[@id="BVRRContainer"]/div/div/div/div/div[3]/div/button')

        next_link = browser.find_element_by_xpath("//*[contains(text(), 'All the latest product drops, limited offers, in-store event info—straight to your inbox.')]")
        actions = ActionChains(browser)
        actions.move_to_element(next_link).perform()

        load_more = WebDriverWait(browser, 1).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="BVRRContainer"]/div/div/div/div/div[3]/div/button')))
        load_more.click()
        print('click')
      
    except:

        pages_remaining = False
        print('No pages remaining, we can start scrapping !')
# Out:
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# click
# No pages remaining, we can start scrapping !

# %%
reviews = []
stars = []

    #REVIEWS -----------------------------------------------------------------------------------------------------------
    
for comment in browser.find_elements_by_css_selector('div[class = bv-content-details-offset-on]'):
    try:
        review = comment.find_element_by_css_selector('[class = bv-content-summary-body-text]').text
        #print(review)
        reviews.append(review)

    except:
        reviews.append("")

        #STARS ----------------------------------------------------------------------------------------------------------      
for rate in browser.find_elements_by_css_selector('span[class = bv-rating-stars-container]'):
    try :
        star = rate.find_element_by_css_selector('span[class = bv-off-screen]').text
        #print(star)
        stars.append(star)
    except:
        pass
        
    #PAGES ------------------------------------------------------------------------------------------------------------

# %%
len(reviews), len(stars)
# Out:
# (3653, 3653)

# %%
reviews[:10]
# Out:
# ['This foundation is just perfect! I love the coverage, the finish, the color, everything! I have tried others but I keep coming back to this one.',
#  'I have been using Clinique for years, but they changed their formula recently, so I went on the hunt for a foundation for my extremely sensitive skin. I’ve definitely found it! I love all the shades offered, it blends great, and it has not caused any sort of breakout. (Like I said....extremely sensitive skin here!) I’ll definitely be buying more Fenty in the future!',
#  'I bought my Fenty makeup about a month ago and I just love it',
#  'I like my foundation so much Thanks Fenty krrrrrrrrr',
#  'My purchase of the Fenty foundation and blotter did not arrive the first time. Customer service was exceptional to get it out to me a second time. Within one week of use, my skin broke out. Badly. It was somewhat oily after a couple hours. The blotter compact absorbed the shine but yielding my skin more of a pale white than my natural vibrant color. The blotter is a great idea if the makeup you use is going to give a shine or make your skin oily. Minus the break out after the first use, it’s ok for an event I guess. I wouldn’t use for daily wear. Not for myself. I went back to my Estée Lauder.',
#  'I have tried so many foundations and this one is perfect for my skin but I do feel that the Fenty primer and foundation match better together better than trying to use any other primer with this foundation',
#  "I love this product it was my first time trying it and I'm glad I did. It melts onto your skin like butter and blends in so quick and easily. I'm not a person who knows how to apply makeup very well but this is so smooth it's easy.",
#  'Used Mac for the past 15 years then I tried Fenty. My makeup stays on all day, no nasty creases at the end of the day omg amazing!!!!!',
#  'Have been using this for about 8 months now and I am glad I switch cause i finally found a foundation that matches my skin perfectly instead of mixing 2 different shades to match!',
#  'I’m very very fair, and bought one of the lightest shades. I don’t think this product was targeted for girls with lighter skin because it just looks so bad on me. It doesn’t blend, it’s so drying, it’s splotchy, so thick, AND DRIES SO FAST. You have to put the foundation on little spots and blend so fast or else you won’t be able to work with it at all.']

# %%
stars[:10]
# Out:
# ['5 out of 5 stars.',
#  '5 out of 5 stars.',
#  '5 out of 5 stars.',
#  '5 out of 5 stars.',
#  '2 out of 5 stars.',
#  '5 out of 5 stars.',
#  '5 out of 5 stars.',
#  '5 out of 5 stars.',
#  '4 out of 5 stars.',
#  '1 out of 5 stars.']

# %% [markdown]
# _________

# %% [markdown]
# ## Create a dataframe from it:

# %%
import pandas as pd
import numpy as np
import re

# %%
FDT = {"review" : reviews, "rating": stars}
FDT = pd.DataFrame(FDT)
FDT
# Out:
#                                                  review             rating
# 0     This foundation is just perfect! I love the co...  5 out of 5 stars.
# 1     I have been using Clinique for years, but they...  5 out of 5 stars.
# 2     I bought my Fenty makeup about a month ago and...  5 out of 5 stars.
# 3     I like my foundation so much Thanks Fenty krrr...  5 out of 5 stars.
# 4     My purchase of the Fenty foundation and blotte...  2 out of 5 stars.
# 5     I have tried so many foundations and this one ...  5 out of 5 stars.
# 6     I love this product it was my first time tryin...  5 out of 5 stars.
# 7     Used Mac for the past 15 years then I tried Fe...  5 out of 5 stars.
# 8     Have been using this for about 8 months now an...  4 out of 5 stars.
# 9     I’m very very fair, and bought one of the ligh...  1 out of 5 stars.
# 10    I Love the way it feels on my skin has a silk ...  5 out of 5 stars.
# 11    This foundation leaves my skin looking flawles...  4 out of 5 stars.
# 12    This foundation is so light and smooth when I ...  5 out of 5 stars.
# 13    I have been using Fenty foundation and conseal...  5 out of 5 stars.
# 14    I love this foundation the very nice coverage ...  4 out of 5 stars.
# 15    I love the fenty 450 foundation its flawless o...  5 out of 5 stars.
# 16    At first I thought I brought the wrong shade c...  5 out of 5 stars.
# 17    I absolutely LOVE the look and feel of this pr...  5 out of 5 stars.
# 18    Perfect match! Great coverage! Light weight an...  5 out of 5 stars.
# 19    I loved my foundation and I totally recommend ...  5 out of 5 stars.
# 20    I’ve been using the Fenty Pro Filt’r foundatio...  5 out of 5 stars.
# 21    First time purchasing any type of foundation a...  5 out of 5 stars.
# 22    Wish I could return it all. Looks terrible. I ...  1 out of 5 stars.
# 23    This is my second time purchasing the foundati...  5 out of 5 stars.
# 24    I love all the products I received. They are d...  5 out of 5 stars.
# 25    I absolutely LOVE this foundation! Keeps me ma...  5 out of 5 stars.
# 26    Welp! Rihanna wanted a foundation that looked ...  5 out of 5 stars.
# 27    My mom loves this. She made me buy it for the ...  5 out of 5 stars.
# 28    I love full coverage foundations but this is m...  5 out of 5 stars.
# 29    Pure Magic, I’m so pleased with my purchase , ...  5 out of 5 stars.
# ...                                                 ...                ...
# 3623  After many years spent mixing foundations I no...  5 out of 5 stars.
# 3624  This is a fantastic foundation. It's matte but...  5 out of 5 stars.
# 3625  I just purchased the Pro Filt'r foundation in ...  5 out of 5 stars.
# 3626  OMG I love it! It's lightweight, full coverage...  5 out of 5 stars.
# 3627  For a long time I've always mixed my foundatio...  5 out of 5 stars.
# 3628  I never go out my way to review products but t...  5 out of 5 stars.
# 3629  tried on 340 yesterday in store (Sephora), onl...  4 out of 5 stars.
# 3630  This foundation is everything! It seriously fe...  5 out of 5 stars.
# 3631  I just bought this, and it looks so, so ,so wo...  5 out of 5 stars.
# 3632  I don't wear makeup solely because I don't lik...  5 out of 5 stars.
# 3633  This is my new favourite - it glides on so smo...  5 out of 5 stars.
# 3634  This product is amazing! It is available in ma...  5 out of 5 stars.
# 3635  this foundation is everything it's hyped up to...  5 out of 5 stars.
# 3636  I've been looking forward to the release of fo...  5 out of 5 stars.
# 3637  I am so happy I spent my coins on this!!!! Rih...  5 out of 5 stars.
# 3638  Absoulutly amazing. Not oily, perfect price, g...  5 out of 5 stars.
# 3639  The following review is about the foundation, ...  5 out of 5 stars.
# 3640  I bought this foundation today in Sephora and ...  5 out of 5 stars.
# 3641  I never had a foundation that was sooooo good....  5 out of 5 stars.
# 3642  The shade range is amazing. This foundation is...  5 out of 5 stars.
# 3643  I love that this foundation came out initially...  5 out of 5 stars.
# 3644  man riri you did the thang girl, its lightweig...  5 out of 5 stars.
# 3645  This foundation is great and WEIGHTLESS! It do...  5 out of 5 stars.
# 3646  This is absolutely amazing! This is the most l...  5 out of 5 stars.
# 3647  This foundations feels so light weight It's am...  5 out of 5 stars.
# 3648  I bought this foundation as soon as sephora op...  5 out of 5 stars.
# 3649  Flawless on my skin! I am already in awe with ...  5 out of 5 stars.
# 3650  This product is available is so many shades, a...  5 out of 5 stars.
# 3651  I just bought so many products from this line ...  5 out of 5 stars.
# 3652  Has a great blurring effect. It blends so nice...  5 out of 5 stars.
#
# [3653 rows x 2 columns]

# %%
FDT.to_csv(r'C:\Users\amnad\Documents\DATA_IA\PYTHON\NLP\NLP PROJET_FENTY\FDT_FT.csv')

# %% [markdown]
# _________

# %%
import pandas as pd

# %%
profiltr = pd.read_csv(r'C:\Users\amnad\Documents\DATA_IA\PYTHON\NLP\NLP PROJET_FENTY\FDT_FT.csv')
profiltr = profiltr.drop(columns = "Unnamed: 0")

# %%
profiltr.head()
# Out:
#                                               review             rating
# 0  This foundation is just perfect! I love the co...  5 out of 5 stars.
# 1  I have been using Clinique for years, but they...  5 out of 5 stars.
# 2  I bought my Fenty makeup about a month ago and...  5 out of 5 stars.
# 3  I like my foundation so much Thanks Fenty krrr...  5 out of 5 stars.
# 4  My purchase of the Fenty foundation and blotte...  2 out of 5 stars.
